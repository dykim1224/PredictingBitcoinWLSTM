# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
file_path = r"C:\Users\jhkju\Documents\GoogleTrend_RelatedQuries2.csv"

df = pd.read_csv(file_path)
df
# Out:
#                      TOP  TOP_WEIGHT                   RISING RISING_PER  \
# 0          bitcoin price         100           hawk tuah coin     soared
# 1          bitcoin stock          15                paul down   +1\t600%
# 2            bitcoin usd          13  why is bitcoin going up       200%
# 3    bitcoin stock price          11      who started bitcoin       190%
# 4      bitcoin price usd          11       bitcoin price 2013       110%
# ..                   ...         ...                      ...        ...
# 618             ethereum           4     bitcoin halving 2020       500%
# 619        bitcoin value           4        dow jones futures       300%
# 620  bitcoin price today           4        elon musk bitcoin       300%
# 621  how much is bitcoin           4              tesla stock       250%
# 622       bitcoin to usd           4             boeing stock       250%
#
#                     START_DATE                   END_DATE
# ...

# %%
rising = df['RISING']
text_data = " ".join(rising.astype(str))

stop_words = set(STOPWORDS)
custom_stopwords = {"https", "co", "RT", "will", "el", "news", "sec", "date", "time", "un"} 
stop_words.update(custom_stopwords)

wordcloud = WordCloud(
    width=800,
    height=400,
    max_words=50,
    background_color="white",
    stopwords=stop_words,
    collocations=False,
    normalize_plurals=False,
    contour_color="steelblue",
    contour_width=1,
    scale=2
).generate(text_data)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Related Quries With Bitcoin", fontsize=16)
plt.show()
